# %% [markdown]
# Transformation des fichiers stéréo en mono

# %%
import pandas as pd

# %%
df = pd.read_table("./sound_features.csv", sep=',' , encoding='utf-8-sig')

# %%
df
# Out:
#     Sample_name_simple Sample_name  Sample_number  Sound_number  mass_ini  \
# 0             L_pl_a_1          S1              1             1   3458.07
# 1             L_pl_a_2          S1              1             2   3458.07
# 2             L_pl_a_3          S1              1             3   3458.07
# 3             L_pl_a_4          S1              1             4   3458.07
# 4             L_pl_a_5          S1              1             5   3458.07
# ..                 ...         ...            ...           ...       ...
# 154          S_pt_d2_1         S27             27             1    617.75
# 155          S_pt_d2_3         S27             27             3    617.75
# 156          S_pt_d3_3         S28             28             3      0.00
# 157          S_pt_d4_2         S29             29             2      0.00
# 158          S_pt_d4_3         S29             29             3      0.00
#
#       mass_0   mass_n  mass_end  f1_ini  a1_ini  ...   rms_ini  centroid_ini  \
# ...
